# %%
import pandas as pd

listings = pd.read_csv("../data/raw/listings.csv")
calendar = pd.read_csv("../data/raw/calendar.csv")
reviews = pd.read_csv("../data/raw/reviews.csv")
neighbourhoods = pd.read_csv("../data/raw/neighbourhoods.csv")

# %%
# Section 3.2: Data Cleaning & Standardization
# Task: Clean the price column

listings["price"] = (
    listings["price"]
    .astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

# %%
# Section 3.2: Data Cleaning & Standardization
# Task: Standardize date fields

listings["last_scraped"] = pd.to_datetime(listings["last_scraped"])
calendar["date"] = pd.to_datetime(calendar["date"])
reviews["date"] = pd.to_datetime(reviews["date"])

# %%
# Section 3.2: Data Cleaning & Standardization
# Task: Save cleaned datasets

listings.to_csv(
    "../data/processed/listings_cleaned.csv",
    index=False
)

calendar.to_csv(
    "../data/processed/calendar_cleaned.csv",
    index=False
)

reviews.to_csv(
    "../data/processed/reviews_cleaned.csv",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      10     "../data/processed/calendar_cleaned.csv",
#      11     index=False
#      12 )
#      13
# ---> 14 reviews.to_csv(
#      15     "../data/processed/reviews_cleaned.csv",
#      16     index=False
#      17 )
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\io\formats\csvs.py:272, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)    260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
# --> 272     self._save()
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\io\formats\csvs.py:277, in CSVFormatter._save(self)
#     275 if self._need_to_save_header:
#     276     self._save_header()
# --> 277 self._save_body()
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\io\formats\csvs.py:315, in CSVFormatter._save_body(self)
#     313 if start_i >= end_i:
#     314     break
# --> 315 self._save_chunk(start_i, end_i)
#
# File c:\Users\Poornima Liyanage\Documents\GitHub\HostLens\venv\Lib\site-packages\pandas\io\formats\csvs.py:330, in CSVFormatter._save_chunk(self, start_i, end_i)
#     323 data = list(res._iter_column_arrays())
#     325 ix = (
#     326     self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     327     if self.nlevels != 0
#     328     else np.empty(end_i - start_i)
#     329 )
# --> 330 libwriters.write_csv_rows(
#     331     data,
#     332     ix,
#     333     self.nlevels,
#     334     self.cols,
#     335     self.writer,
#     336 )
#
# File pandas/_libs/writers.pyx:73, in pandas._libs.writers.write_csv_rows()
# ---> 73 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# # Data Cleaning and Standardization
#
# This notebook performs data cleaning and standardization on the Inside Airbnb dataset for New York City.
#
# The main objectives are:
#
# - Clean and standardize price columns.
# - Convert date fields to a consistent format.
# - Handle missing values.
# - Prepare datasets for downstream analysis and modeling.
